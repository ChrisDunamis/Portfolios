# %% [markdown]
# __Name:__ Chris Dunamis __<span style="padding-left: 730px;">Subject:</span>__ Data Analysis
#
# # __<span style="color: green"><center><u>PANDAS & PYTHON PROGRAMMING LANGUAGE FOR DATA ANALYSIS</u></center></span>__

# %%
import os
import zipfile
import warnings
import pandas as pd
import seaborn as sns

warnings.filterwarnings("ignore")


zip_dataset = "pokemon-all-status-data.zip"
dataset_filename = "Pokemon Data.csv"
dataset_path = "/Users/Chris-Dunamis/Documents/Portfolios/Python/Projects/freeCodeCamp - Pandas & Python for Data "\
    "Analysis/Datasets/Pokemon/"

for directory_path, directory_names, filenames in os.walk(dataset_path):
    # os.walk: This is a "Directory tree generator", which traverses through the:
    #       Relative Path   - (The directory_path specified)
    #       Directory Names - (A list of Directory Name(s) from the Relative Path)
    #       File Names      - (A list of File Name(s) from the Relative Path)
    if dataset_filename in filenames:
        print(f"The 'Dataset: {dataset_filename}' exist in:" + "\n\n" + 
              
              f"PATH: {dataset_path}")
        
        for i, filename in enumerate(filenames):
            print(f"    |File {(i + 1)}|: {filename}")

        break
else:
    print(f"The 'Dataset: {dataset_filename}' does not exist in:" + "\n" + 
            f"PATH: {dataset_path}" + "\n\n" + 
            
            "Commencing Dataset Download..." + "\n" + 
            ('-' * 138))
    
    # (Stage 1): Since we are located in the "Current Working Directory: dataset_path", the dataset is set to be 
    #            downloaded here:
    # %cd ./Datasets/Pokemon/

    # (Stage 2): In order for this line of code to be executed, the Module: Kaggle needs to be imported to your current 
    #            VenV and the Kaggle API needs to be installed onto the system:
    # !kaggle datasets download --force -d takamasakato/pokemon-all-status-data
    
    # (Stage 3): When the dataset is successfully downloaded, the code below is executed to extract the files from the 
    #            zipped file:
    with zipfile.ZipFile(zip_dataset, 'r') as zip_ref:  # The Current Working Directory is where the un-zipped 
        zip_ref.extractall(dataset_path)                # filename(s)/dataset(s) is located...

    # (Stage 4): For sanity check, this brings us back to the working directory of the Notebook:
    print(('-' * 138) + "\n" + 
          "Now working at home directory..." + "\n" + 
          "PATH:", end=' ')
    # %cd ../../
# Out:
# The 'Dataset: Pokemon Data.csv' exist in:
#
# PATH: /Users/Chris-Dunamis/Documents/Portfolios/Python/Projects/freeCodeCamp - Pandas & Python for Data Analysis/Datasets/Pokemon/
#     |File 1|: .DS_Store
#     |File 2|: Pokemon Data.csv
#     |File 3|: pokemon.csv

# %%
df = pd.read_csv("./Datasets/Pokemon/pokemon.csv")

df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.drop(columns=["#"], axis=1, inplace=True)
df.to_csv("./Datasets/Pokemon/Pokemon Data.csv", index=False)

df = pd.read_csv("./Datasets/Pokemon/Pokemon Data.csv")

df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe(include="all").T
# Out:
#             count unique        top freq      mean        std    min    25%  \
# Name          800    800  Bulbasaur    1       NaN        NaN    NaN    NaN
# Type 1        800     18      Water  112       NaN        NaN    NaN    NaN
# Type 2        414     18     Flying   97       NaN        NaN    NaN    NaN
# Total       800.0    NaN        NaN  NaN  435.1025  119.96304  180.0  330.0
# HP          800.0    NaN        NaN  NaN  69.25875  25.534669    1.0   50.0
# Attack      800.0    NaN        NaN  NaN  79.00125  32.457366    5.0   55.0
# Defense     800.0    NaN        NaN  NaN   73.8425  31.183501    5.0   50.0
# Sp. Atk     800.0    NaN        NaN  NaN     72.82  32.722294   10.0  49.75
# Sp. Def     800.0    NaN        NaN  NaN   71.9025  27.828916   20.0   50.0
# Speed       800.0    NaN        NaN  NaN   68.2775  29.060474    5.0   45.0
# Generation  800.0    NaN        NaN  NaN   3.32375    1.66129    1.0    2.0
# ...

# %% [markdown]
# <br>
#
# #### __Distribution of Pokémon Types:__

# %%
df["Type 1"].value_counts().plot(title="Pokémon Types", kind="pie", autopct="%1.1f%%", cmap="tab20c", figsize=(10, 8));

# %% [markdown]
# <br>
#
# #### __Distribution of Pokémon Total Points:__

# %%
df["Total"].plot(title="Pokémon Total Points", kind="hist", figsize=(8, 6));

# %%
df["Total"].plot(title="Pokémon Total Points", kind="box", grid=True, vert=False, figsize=(8, 6));

# %% [markdown]
# <br>
#
# #### __Distribution of Legendary Pokémons:__

# %%
df["Legendary"].value_counts().plot(
    title="Legendary Pokémons", kind="pie", autopct="%1.2f%%", cmap="Set3", figsize=(10, 8)
);

# %% [markdown]
# <br>
#
# ## __Basic Filtering__
#
# Let's start with a few simple activities regarding filtering.
#
# ___(1): How many Pokémons exist with an `Attack` value greater than 150?___
#
# Doing a little bit of visual exploration, we can have a sense of the most "powerful" Pokémons (defined by their "Attack" feature). A boxplot is a greater way to visualise this:

# %%
ax = sns.boxplot(data=df, x="Attack")
ax.set_title("Pokémons with an Attack value greater than 150");

# %%
df.head(1)
# Out:
#         Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  Bulbasaur  Grass  Poison    318  45      49       49       65       65
#
#    Speed  Generation  Legendary
# 0     45           1      False

# %%
df.loc[df["Attack"] > 150]
# Out:
#                         Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 137        PinsirMega Pinsir      Bug    Flying    600   65     155      120
# 141    GyaradosMega Gyarados    Water      Dark    640   95     155      109
# 163      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 232  HeracrossMega Heracross      Bug  Fighting    600   80     185      115
# 268  TyranitarMega Tyranitar     Rock      Dark    700  100     164      150
# 279    BlazikenMega Blaziken     Fire  Fighting    630   80     160       80
# 313                  Slaking   Normal       NaN    670  150     160      100
# 387      BanetteMega Banette    Ghost       NaN    555   64     165       75
# 424    GroudonPrimal Groudon   Ground      Fire    770  100     180      160
# 426    RayquazaMega Rayquaza   Dragon    Flying    780  105     180      100
# 429       DeoxysAttack Forme  Psychic       NaN    600   50     180       20
# ...

# %%
df.query("Attack > 150")
# Out:
#                         Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 137        PinsirMega Pinsir      Bug    Flying    600   65     155      120
# 141    GyaradosMega Gyarados    Water      Dark    640   95     155      109
# 163      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 232  HeracrossMega Heracross      Bug  Fighting    600   80     185      115
# 268  TyranitarMega Tyranitar     Rock      Dark    700  100     164      150
# 279    BlazikenMega Blaziken     Fire  Fighting    630   80     160       80
# 313                  Slaking   Normal       NaN    670  150     160      100
# 387      BanetteMega Banette    Ghost       NaN    555   64     165       75
# 424    GroudonPrimal Groudon   Ground      Fire    770  100     180      160
# 426    RayquazaMega Rayquaza   Dragon    Flying    780  105     180      100
# 429       DeoxysAttack Forme  Psychic       NaN    600   50     180       20
# ...

# %%
print("A sum of [{pokemon_sum}] Pokémons exist with an Attack value greater than 150.".format(
    pokemon_sum=df.loc[(df["Attack"] > 150), "Name"].value_counts().sum()
))
# Out:
# A sum of [18] Pokémons exist with an Attack value greater than 150.

# %% [markdown]
# <br>
#
# ___(2): Select all Pokémons with a Speed of `10` or less___
#
# Use filtering to select those "slow" Pokémons with a Speed of `10` or less. Store your results in a variable `slow_pokemons_df`.

# %%
ax = sns.boxplot(data=df, x="Speed")
ax.set_title("Pokémons with a Speed of 10 or less");

# %%
slow_pokemons_df = df.query("Speed <= 10")

slow_pokemons_df
# Out:
#           Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230    Shuckle     Bug   Rock    505   20      10      230       10      230
# 359   Trapinch  Ground    NaN    290   45     100       45       45       45
# 486     Bonsly    Rock    NaN    290   50      80       95       10       45
# 495   Munchlax  Normal    NaN    390  135      85       40       40       85
# 658  Ferroseed   Grass  Steel    305   44      50       91       24       86
#
#      Speed  Generation  Legendary
# 230      5           2      False
# 359     10           3      False
# 486     10           4      False
# 495      5           4      False
# 658     10           5      False

# %% [markdown]
# <br>
#
# ___(3): How many Pokémons have a `Sp. Def` value of 25 or less___
#
# The `Sp. Def` value indicates the defense power of a Pokémon against Special abilities. How many Pokémons have a value of `25` or less?

# %%
df.loc[df["Sp. Def"] <= 25]
# Out:
#                    Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 13             Caterpie      Bug     NaN    195   45      30       35
# 14              Metapod      Bug     NaN    205   50      20       55
# 16               Weedle      Bug  Poison    195   40      35       30
# 17               Kakuna      Bug  Poison    205   45      25       50
# 44           Jigglypuff   Normal   Fairy    270  115      45       20
# 97             Shellder    Water     NaN    305   30      65      100
# 106              Krabby    Water     NaN    325   30     105       90
# 125              Horsea    Water     NaN    295   30      40       70
# 139            Magikarp    Water     NaN    200   20      10       55
# 188           Igglybuff   Normal   Fairy    210   90      30       15
# 209              Wooper    Water  Ground    210   55      45       45
# 289             Silcoon      Bug     NaN    205   50      35       55
# ...

# %%
print("A sum of [{pokemon_sum}] Pokémons have a Sp. Def value of 25 or less.".format(
    pokemon_sum=(df["Sp. Def"] <= 25).sum()
))
# Out:
# A sum of [18] Pokémons have a Sp. Def value of 25 or less.

# %% [markdown]
# <br>
#
# ___(4): Select all the Legendary Pokémons___
#
# Select only Pokémons that are Legendary and store the result in the variable `legendary_df`.

# %%
legendary_df = df.loc[df["Legendary"]]

legendary_df
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 156             Articuno       Ice    Flying    580   90      85      100
# 157               Zapdos  Electric    Flying    580   90      90       85
# 158              Moltres      Fire    Flying    580   90     100       90
# 162               Mewtwo   Psychic       NaN    680  106     110       90
# 163  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..                   ...       ...       ...    ...  ...     ...      ...
# 795              Diancie      Rock     Fairy    600   50     100      150
# 796  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 797  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 798   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 799            Volcanion      Fire     Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# <br>
#
# ___(5): Find the outlier___
#
# Take a look at the scatterplot that correlates Pokémons Attack and Defense. What's the `Name` of the Pokémon that is a clear outlier strong `Defense`, but very low `Attack`).

# %%
sns.set_style(
    "ticks", 
    {"axes.grid" : True}
)

ax = sns.scatterplot(data=df, x="Defense", y="Attack")

ax.set_title("Pokémons that are clearly outliers in terms of Attack / Defense")
ax.annotate(
    "Who's this guy?", xy=(228, 10), xytext=(150, 10), color="red", arrowprops=dict(arrowstyle="->", color="black")
);

# %%
outlier_result = df.sort_values(by=["Defense", "Attack"], ascending=[False, True])

print("From the table below, the Pokémon that is a clear outlier in strong Defense, but very low Attack is, " + 
      "'{pokemon_name}'.".format(pokemon_name=outlier_result.head(1).sum()[0]
      ))
outlier_result.head()
# Out:
# From the table below, the Pokémon that is a clear outlier in strong Defense, but very low Attack is, 'Shuckle'.
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 230              Shuckle    Bug    Rock    505  20      10      230       10
# 224  SteelixMega Steelix  Steel  Ground    610  75     125      230       55
# 333    AggronMega Aggron  Steel     NaN    630  70     140      230       60
# 223              Steelix  Steel  Ground    510  75      85      200       55
# 414             Regirock   Rock     NaN    580  80     100      200       50
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 224       95     30           2      False
# 333       80     50           3      False
# 223       65     30           2      False
# 414      100     50           3       True
